# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
#show plots inline
# %matplotlib inline
import statsmodels.formula.api as sm
from scipy import stats

# %%
students = pd.read_csv("CumGPAByCount.csv",header=0,sep=',')
students = students.drop('entryId',1)

# %%
students.head(1)
# Out:
#    cnt  CUM_GPA
# 0    1     1.71

# %%
students.mean()
# Out:
# cnt        1.632330
# CUM_GPA    3.461273
# dtype: float64

# %%
sns.pairplot(students, size=4)
plt.show()

# %%
model = sm.ols(formula='CUM_GPA ~ cnt',data = students)
model = model.fit()

model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                CUM_GPA   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     3.987
# Date:                Sun, 24 Sep 2017   Prob (F-statistic):             0.0459
# Time:                        22:29:20   Log-Likelihood:                -1234.8
# No. Observations:                2592   AIC:                             2474.
# Df Residuals:                    2590   BIC:                             2485.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      3.4377      0.014    244.253      0.000       3.410       3.465
# cnt            0.0144      0.007      1.997      0.046       0.000       0.029
# ==============================================================================
# Omnibus:                      557.577   Durbin-Watson:                   0.443
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1175.535
# Skew:                          -1.242   Prob(JB):                    5.44e-256
# Kurtosis:                       5.172   Cond. No.                         4.29
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
regPlot = sns.lmplot(x='cnt',y='CUM_GPA',data=students,fit_reg=True)

# %%
residPlot = sns.residplot(students['cnt'],students['CUM_GPA'],lowess=True)

# %%
plt.hist(model.resid_pearson)
# Out:
# (array([   1.,    3.,    8.,   20.,   50.,  127.,  273.,  486.,  761.,  642.]),
#  array([-5.81405116, -5.0907559 , -4.36746064, -3.64416539, -2.92087013,
#         -2.19757487, -1.47427962, -0.75098436, -0.0276891 ,  0.69560615,
#          1.41890141]),
#  <a list of 10 Patch objects>)

# %%
prob = stats.probplot(model.resid_pearson,plot=plt)
