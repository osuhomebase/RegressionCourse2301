# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
#show plots inline
# %matplotlib inline
import statsmodels.formula.api as sm
from scipy import stats

# %%
students = pd.read_csv("CumGPAByCount.csv",header=0,sep=',')
students = students.drop('entryId',1)

# %%
students.head(1)
# Out:
#    cnt  CUM_GPA
# 0    1     1.71

# %%
students.mean()
# Out:
# cnt        1.598414
# CUM_GPA    3.470331
# dtype: float64

# %%
sns.pairplot(students, size=4)
plt.show()

# %%
model = sm.ols(formula='CUM_GPA ~ cnt',data = students)
model = model.fit()


model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                CUM_GPA   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     3.345
# Date:                Tue, 26 Sep 2017   Prob (F-statistic):             0.0676
# Time:                        23:17:45   Log-Likelihood:                -967.60
# No. Observations:                2144   AIC:                             1939.
# Df Residuals:                    2142   BIC:                             1951.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      3.4467      0.015    224.836      0.000       3.417       3.477
# cnt            0.0148      0.008      1.829      0.068      -0.001       0.031
# ==============================================================================
# Omnibus:                      393.151   Durbin-Watson:                   0.002
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              688.458
# Skew:                          -1.161   Prob(JB):                    3.19e-150
# Kurtosis:                       4.520   Cond. No.                         4.29
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
regPlot = sns.lmplot(x='cnt',y='CUM_GPA',data=students,fit_reg=True)

# %%
residPlot = sns.residplot(students['cnt'],students['CUM_GPA'])

# %%
plt.hist(model.resid_pearson)
# Out:
# (array([   1.,    3.,    6.,   20.,   40.,  107.,  231.,  425.,  715.,  598.]),
#  array([-5.94068058, -5.20631828, -4.47195597, -3.73759367, -3.00323137,
#         -2.26886907, -1.53450677, -0.80014447, -0.06578217,  0.66858013,
#          1.40294243]),
#  <a list of 10 Patch objects>)

# %%
prob = stats.probplot(model.resid_pearson,plot=plt)

# %%
from statsmodels.stats.outliers_influence import summary_table
from statsmodels.sandbox.regression.predstd import wls_prediction_std

re = sm.OLS(students['CUM_GPA'], students['cnt']).fit()
prstd, iv_l, iv_u = wls_prediction_std(re)


st, data, ss2 = summary_table(re, alpha=0.05)

fittedvalues = data[:,2]
predict_mean_se  = data[:,3]
predict_mean_ci_low, predict_mean_ci_upp = data[:,4:6].T
predict_ci_low, predict_ci_upp = data[:,6:8].T

# check we got the right things
print(np.max(np.abs(re.fittedvalues - fittedvalues)))
print(np.max(np.abs(iv_l - predict_ci_low)))
print(np.max(np.abs(iv_u - predict_ci_upp)))

plt.plot(x, y, 'o')
plt.plot(x, fittedvalues, '-', lw=2)
plt.plot(x, predict_ci_low, 'r--', lw=2)
plt.plot(x, predict_ci_upp, 'r--', lw=2)
plt.plot(x, predict_mean_ci_low, 'r--', lw=2)
plt.plot(x, predict_mean_ci_upp, 'r--', lw=2)
plt.show()
# Out:
# 0.0
# 0.0
# 0.0
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-43-037ec122a875> in <module>()
#      19 print(np.max(np.abs(iv_u - predict_ci_upp)))
#      20
# ---> 21 plt.plot(x, y, 'o')
#      22 plt.plot(x, fittedvalues, '-', lw=2)
#      23 plt.plot(x, predict_ci_low, 'r--', lw=2)
#
# NameError: name 'x' is not defined
